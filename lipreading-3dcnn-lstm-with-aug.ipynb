# %%
import os
import numpy as np

# %%
videos = np.load('/kaggle/input/npy-dikit/videosCorrectDikit.npy')
labels = np.load('/kaggle/input/npy-dikit/labelsCorrectDikit.npy')
videos = videos / 255

# %% [markdown]
# # Developing Model

# %%
# !pip install protobuf==3.20.*
# Out:
# Requirement already satisfied: protobuf==3.20.* in /usr/local/lib/python3.11/dist-packages (3.20.3)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras import models, Input
import gc
from tensorflow.keras import regularizers
# Out:
# 2026-01-07 16:13:35.613729: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767802415.637227     160 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767802415.644442     160 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
encoder = LabelEncoder()
encoder.fit(labels)
print(encoder.classes_)
print(len(encoder.classes_))
encoded_labels = encoder.transform(labels)
labels = encoded_labels
# Out:
# ['air' 'bakso' 'doa' 'kopi' 'novel' 'puding' 'rumus' 'surat']
# 8

# %%
x_train, x_test, y_train, y_test = train_test_split(videos, labels, test_size=0.3, random_state=42)
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

del videos

# %%
gc.collect()
# !cat /proc/meminfo | grep Mem
# Out:
# MemTotal:       32873508 kB
# MemFree:        15772272 kB
# MemAvailable:   19431516 kB

# %%
label_dict = {0: 'air', 1: 'bakso', 2: 'doa', 3: 'kopi', 4: 'novel', 5: 'puding', 6: 'rumus', 7: 'surat'}

# %%
import matplotlib.pyplot as plt

classes = np.unique(labels) 
counts = np.bincount(labels, minlength=len(classes)) 
max_len = max([len(label_dict[i]) for i in range(len(label_dict))]) 
for i, count in enumerate(counts): 
    class_name = label_dict[i].ljust(max_len)
    print("{}    {} counts".format(class_name, count))

plt.figure(figsize=(8, 6))
plt.rcParams.update({'font.size': 12})
plt.hist(labels, bins = len(classes), width=0.8)
plt.xticks(range(len(classes)), [label_dict[i] for i in range(len(classes))], rotation = 45, ha = 'right')
plt.xlabel("Classes")
plt.ylabel("Counts")
plt.title("Class Distribution")
plt.show()
# Out:
# air       164 counts
# bakso     152 counts
# doa       153 counts
# kopi      159 counts
# novel     152 counts
# puding    152 counts
# rumus     157 counts
# surat     160 counts

# %%
data_augmentation  = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomZoom(0.05),
    tf.keras.layers.RandomRotation(0.05),
    tf.keras.layers.RandomContrast(0.05)
], name="lip_augmentation")

inputs = Input((45, 80, 112, 3))

x = tf.keras.layers.TimeDistributed(data_augmentation)(inputs)
x = tf.keras.layers.Conv3D(16, (3, 3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling3D((1, 2, 2))(x)
x = tf.keras.layers.Conv3D(32, (3, 3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling3D((1, 2, 2))(x)
x = tf.keras.layers.Conv3D(64, (3, 3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling3D((1, 2, 2))(x)

x = tf.keras.layers.TimeDistributed(tf.keras.layers.Flatten())(x)
x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True))(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=False))(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = tf.keras.layers.Dense(8, activation='softmax')(x)
# Out:
# I0000 00:00:1767802433.466416     160 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model = models.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)
y_val = tf.keras.utils.to_categorical(y_val)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 45, 80, 112, 3) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 45, 80, 112, 3) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 45, 80, 112,    │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 45, 40, 56, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 45, 40, 56, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 45, 20, 28, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 45, 20, 28, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 45, 10, 14, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 45, 8960)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 45, 128)        │     4,620,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 45, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,791,176 (18.28 MB)
#  Trainable params: 4,791,176 (18.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
x_train.shape
# Out:
# (874, 45, 80, 112, 3)

# %%
from tensorflow.keras.callbacks import EarlyStopping

history = model.fit(
    x_train,
    y_train,
    batch_size = 16,
    validation_data = (x_val, y_val),
    epochs = 100,
    callbacks = EarlyStopping(monitor = 'val_accuracy', patience  = 5, restore_best_weights = True)
)
# Out:
# Epoch 1/100
# I0000 00:00:1767802493.537577     217 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 72s 384ms/step - accuracy: 0.1321 - loss: 2.0876 - val_accuracy: 0.2181 - val_loss: 2.0625
# Epoch 2/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 0.2109 - loss: 2.0291 - val_accuracy: 0.4202 - val_loss: 1.7385
# Epoch 3/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.5084 - loss: 1.5849 - val_accuracy: 0.6383 - val_loss: 1.2060
# Epoch 4/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.6699 - loss: 1.0995 - val_accuracy: 0.7021 - val_loss: 0.9234
# Epoch 5/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.7856 - loss: 0.7781 - val_accuracy: 0.7660 - val_loss: 0.7205
# Epoch 6/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 0.8453 - loss: 0.5828 - val_accuracy: 0.8191 - val_loss: 0.5940
# Epoch 7/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.8643 - loss: 0.4844 - val_accuracy: 0.8245 - val_loss: 0.5441
# Epoch 8/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 255ms/step - accuracy: 0.9046 - loss: 0.3820 - val_accuracy: 0.8723 - val_loss: 0.4091
# Epoch 9/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9346 - loss: 0.2729 - val_accuracy: 0.9149 - val_loss: 0.3470
# Epoch 10/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9476 - loss: 0.2224 - val_accuracy: 0.8830 - val_loss: 0.3858
# Epoch 11/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9302 - loss: 0.2488 - val_accuracy: 0.8936 - val_loss: 0.3366
# Epoch 12/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9564 - loss: 0.1790 - val_accuracy: 0.8989 - val_loss: 0.3143
# Epoch 13/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 0.9566 - loss: 0.1721 - val_accuracy: 0.9149 - val_loss: 0.3634
# Epoch 14/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9737 - loss: 0.1306 - val_accuracy: 0.9202 - val_loss: 0.2694
# Epoch 15/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 0.9802 - loss: 0.1095 - val_accuracy: 0.9149 - val_loss: 0.2620
# Epoch 16/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 252ms/step - accuracy: 0.9828 - loss: 0.0929 - val_accuracy: 0.9043 - val_loss: 0.2499
# Epoch 17/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9841 - loss: 0.1050 - val_accuracy: 0.9149 - val_loss: 0.2787
# Epoch 18/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 0.9943 - loss: 0.0773 - val_accuracy: 0.8936 - val_loss: 0.3258
# Epoch 19/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 255ms/step - accuracy: 0.9699 - loss: 0.1178 - val_accuracy: 0.9309 - val_loss: 0.2352
# Epoch 20/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9734 - loss: 0.0902 - val_accuracy: 0.9255 - val_loss: 0.2144
# Epoch 21/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9691 - loss: 0.1027 - val_accuracy: 0.9202 - val_loss: 0.2587
# Epoch 22/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 0.9891 - loss: 0.0527 - val_accuracy: 0.9362 - val_loss: 0.2162
# Epoch 23/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9876 - loss: 0.0464 - val_accuracy: 0.9096 - val_loss: 0.2439
# Epoch 24/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9821 - loss: 0.0762 - val_accuracy: 0.9415 - val_loss: 0.1918
# Epoch 25/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9943 - loss: 0.0401 - val_accuracy: 0.9149 - val_loss: 0.2519
# Epoch 26/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9947 - loss: 0.0392 - val_accuracy: 0.9255 - val_loss: 0.2003
# Epoch 27/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9979 - loss: 0.0282 - val_accuracy: 0.9309 - val_loss: 0.1838
# Epoch 28/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9992 - loss: 0.0163 - val_accuracy: 0.9468 - val_loss: 0.1701
# Epoch 29/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9309 - val_loss: 0.1962
# Epoch 30/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.9468 - val_loss: 0.2030
# Epoch 31/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9521 - val_loss: 0.1783
# Epoch 32/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9468 - val_loss: 0.1857
# Epoch 33/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.8830 - val_loss: 0.3889
# Epoch 34/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 254ms/step - accuracy: 0.9845 - loss: 0.0654 - val_accuracy: 0.9149 - val_loss: 0.2805
# Epoch 35/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 0.9742 - loss: 0.0912 - val_accuracy: 0.9096 - val_loss: 0.2741
# Epoch 36/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 253ms/step - accuracy: 0.9993 - loss: 0.0321 - val_accuracy: 0.8989 - val_loss: 0.3220

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Val_Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Val_Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Test Evaluation

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Acc: ", test_acc)
print("Test Loss: ", test_loss)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - accuracy: 0.9679 - loss: 0.1105
# Test Acc:  0.9572192430496216
# Test Loss:  0.1240876168012619

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_test_labels = np.argmax(y_test, axis=1)
y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)
report = classification_report(y_test_labels, y_pred)
print(report)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 698ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      0.96      0.98        24
#            2       0.88      0.88      0.88        25
#            3       1.00      1.00      1.00        28
#            4       0.91      1.00      0.95        20
#            5       1.00      0.95      0.98        21
#            6       0.97      1.00      0.98        29
#            7       0.90      0.86      0.88        21
#
#     accuracy                           0.96       187
#    macro avg       0.96      0.96      0.96       187
# weighted avg       0.96      0.96      0.96       187

# %%
import seaborn as sns

conf_matrix = confusion_matrix(y_test_labels, y_pred)
label_strings = [label_dict[i] for i in range(len(label_dict))]
sns.heatmap(conf_matrix, annot=True, cmap="Blues", xticklabels=label_strings, yticklabels=label_strings)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix Predicted VS True")
plt.show()

# %%
# model.save("model_3DCNN+LSTM with Aug.keras")
